# %% [markdown]
# ### Imports

# %%
import os
import sys
import json
import re
import math
import operator
import pandas as pd

# %% [markdown]
# ### This function reads data from the data/ directory
#
# The whole JSON structure was not same for company_info and other_details. I tried to make the structure same across all docs. Though this is not required as we are interested only in Job Description .

# %%
def extract_data(data_type):
    def structure_dict(keys, attribute, d):
        temp = {}
        for key in keys:
            try:
                temp[key] = d[attribute][key]
            except KeyError:
                temp[key] = []
        return temp

    company_info_keys = [u'Company Description', u'Email', u'Company Name', u'Telephone']
    other_details_keys = [u'Industry:', u'Department:', u'Skills:', u'Other Skills:']
    
    data_dict = {}
    for root, subdirs, files in os.walk('data/' + data_type):
        for file in os.listdir(root):
            filePath = os.path.join(root, file)
            if os.path.isdir(filePath):
                pass
            else:
                with open(filePath) as json_data:
                    d = json.load(json_data)
                    if str(os.path.dirname(filePath)) in data_dict.keys(): 
                        data_dict[str(os.path.dirname(filePath))].append(d)
                        company_info = structure_dict(company_info_keys, 'company_info', d)
                        other_details = structure_dict(other_details_keys, 'other_details', d)
                        d.pop('company_info')
                        d.pop('other_details')
                        d['company_info'] = company_info
                        d['other_details'] = other_details
                    else:
                        data_dict[str(os.path.dirname(filePath))] = list()
    return data_dict

# %% [markdown]
# ### Text Preprocessing

# %%
def preprocess(s):
    nonenglish = re.compile(r'[^\x00-\x7F]')
    tabs = re.compile(r'\t')
    spaces = re.compile(r'(\s{2,})')
    weblinks = re.compile(r"""(https?://?(www\.)?(\w+).+) | #http wale links
                                ((www\.)[.^\S]+) | #www wale link
                                ([.^\S]+(\.com)[.^\S]+)|([.^\S]+(\.co\.)[.^\S]+)|([.^\S]+)(\.com) #.com wale links
                            """, flags = re.IGNORECASE | re.VERBOSE)
    htmltags = re.compile(r'&\w*;', flags = re.IGNORECASE)
    numbers = re.compile(r'(\W+)?([0-9]+)(\W+)?')
    speclchars = re.compile(r'[_~@\^\*\(\)\+={}\|\[\]\\/\.,:]')
    if nonenglish.search(s) is None:
        weblinks_removed = re.sub(weblinks, '', s)
        htmltags_removed = re.sub(htmltags, '', weblinks_removed)
        numbers_removed = re.sub(numbers, ' <number> ', htmltags_removed)
        speclchars_removed = re.sub(speclchars, ' ', numbers_removed)
        if len(speclchars_removed.lstrip())>0:
            return speclchars_removed.lower()

# %% [markdown]
# ### Creating Vocablary for term-document matrix

# %%
training = extract_data('training')
bagofwords = []
documents = {}
count = 0
for k, v in training.items():
    for i, item in enumerate(v):
        desc = item['jd_information']['description']
        if len(desc)>0:
            clean_desc = preprocess(desc)
            if type(clean_desc) is unicode:
                if len(clean_desc)>0:
                    documents[(k, count)] = clean_desc
                    bagofwords.extend(clean_desc.split(' '))
                    count += 1 
del training
vocab = set(bagofwords)
print "no. of job descriptions  ", count
del bagofwords
# Out:
# no. of job descriptions   624

# %% [markdown]
# ### Creating the Term-Document matrix as a dataframe

# %%
vectorspace = pd.DataFrame(index=vocab, columns=documents.keys())
vectorspace = vectorspace.fillna(0)
vectorspace.head()
# Out:
#                          (data/training/travel_tourism, 205)  \
#                                                            0
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/agriculture_dairy, 502)  \
#                                                               0
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/travel_tourism, 322)  \
#                                                            0
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/media_dotcom_entertainment, 100)  \
#                                                                        0
# franchiseejob                                                          0
# looking                                                                0
# descriptionagricultural                                                0
# eligible                                                               0
#
#                          (data/training/travel_tourism, 231)  \
#                                                            0
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/media_dotcom_entertainment, 2)  \
#                                                                      0
# franchiseejob                                                        0
# looking                                                              0
# descriptionagricultural                                              0
# eligible                                                             0
#
#                          (data/training/agriculture_dairy, 527)  \
#                                                               0
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/agriculture_dairy, 416)  \
#                                                               0
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/travel_tourism, 129)  \
#                                                            0
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/media_dotcom_entertainment, 40)  \
#                                                                       0
# franchiseejob                                                         0
# looking                                                               0
# descriptionagricultural                                               0
# eligible                                                              0
#
#                                               ...                        \
#                                               ...
# franchiseejob                                 ...
# looking                                       ...
# descriptionagricultural                       ...
# eligible                                      ...
#
#                          (data/training/agriculture_dairy, 558)  \
#                                                               0
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/travel_tourism, 160)  \
#                                                            0
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/travel_tourism, 281)  \
#                                                            0
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/agriculture_dairy, 418)  \
#                                                               0
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/agriculture_dairy, 596)  \
#                                                               0
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/travel_tourism, 186)  \
#                                                            0
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/it_software, 340)  \
#                                                         0
# franchiseejob                                           0
# looking                                                 0
# descriptionagricultural                                 0
# eligible                                                0
#
#                          (data/training/travel_tourism, 307)  \
#                                                            0
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/it_software, 362)  \
#                                                         0
# franchiseejob                                           0
# looking                                                 0
# descriptionagricultural                                 0
# eligible                                                0
#
#                          (data/training/media_dotcom_entertainment, 94)
#                                                                       0
# franchiseejob                                                         0
# looking                                                               0
# descriptionagricultural                                               0
# eligible                                                              0
#
# [5 rows x 624 columns]

# %% [markdown]
# ### Filling up the Term-Document matrix

# %%
for docID, doc in documents.items():
    for word in doc.split(' '):
        vectorspace[docID].loc[word] += 1 
vectorspace.head()
# Out:
#                          (data/training/travel_tourism, 205)  \
#                                                            4
# franchiseejob                                              0
# looking                                                    1
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/agriculture_dairy, 502)  \
#                                                              12
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/travel_tourism, 322)  \
#                                                            2
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/media_dotcom_entertainment, 100)  \
#                                                                        3
# franchiseejob                                                          0
# looking                                                                0
# descriptionagricultural                                                0
# eligible                                                               0
#
#                          (data/training/travel_tourism, 231)  \
#                                                            8
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/media_dotcom_entertainment, 2)  \
#                                                                     24
# franchiseejob                                                        0
# looking                                                              0
# descriptionagricultural                                              0
# eligible                                                             0
#
#                          (data/training/agriculture_dairy, 527)  \
#                                                              15
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/agriculture_dairy, 416)  \
#                                                               6
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/travel_tourism, 129)  \
#                                                           38
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/media_dotcom_entertainment, 40)  \
#                                                                      12
# franchiseejob                                                         0
# looking                                                               0
# descriptionagricultural                                               0
# eligible                                                              0
#
#                                               ...                        \
#                                               ...
# franchiseejob                                 ...
# looking                                       ...
# descriptionagricultural                       ...
# eligible                                      ...
#
#                          (data/training/agriculture_dairy, 558)  \
#                                                              21
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       1
# eligible                                                      0
#
#                          (data/training/travel_tourism, 160)  \
#                                                           37
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/travel_tourism, 281)  \
#                                                            2
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/agriculture_dairy, 418)  \
#                                                               0
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/agriculture_dairy, 596)  \
#                                                              20
# franchiseejob                                                 0
# looking                                                       0
# descriptionagricultural                                       0
# eligible                                                      0
#
#                          (data/training/travel_tourism, 186)  \
#                                                            3
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/it_software, 340)  \
#                                                        19
# franchiseejob                                           0
# looking                                                 0
# descriptionagricultural                                 0
# eligible                                                0
#
#                          (data/training/travel_tourism, 307)  \
#                                                           31
# franchiseejob                                              0
# looking                                                    0
# descriptionagricultural                                    0
# eligible                                                   0
#
#                          (data/training/it_software, 362)  \
#                                                         3
# franchiseejob                                           0
# looking                                                 0
# descriptionagricultural                                 0
# eligible                                                0
#
#                          (data/training/media_dotcom_entertainment, 94)
#                                                                      33
# franchiseejob                                                         0
# looking                                                               0
# descriptionagricultural                                               0
# eligible                                                              0
#
# [5 rows x 624 columns]

# %% [markdown]
# ### Probability of Class

# %%
prob_of_class = {}
for (class_, docID), doc in documents.items():
    if class_ in prob_of_class.keys():
        prob_of_class[class_] += 1
    else:
        prob_of_class[class_] = 0
total = sum(prob_of_class.itervalues(), 0.0)
prob_of_class = {k: v / total for k, v in prob_of_class.iteritems()}
prob_of_class
# Out:
# {'data/training/agriculture_dairy': 0.36935483870967745,
#  'data/training/it_software': 0.09838709677419355,
#  'data/training/media_dotcom_entertainment': 0.19193548387096773,
#  'data/training/travel_tourism': 0.3403225806451613}

# %% [markdown]
# ### Probability of class given a word

# %%
def prob_of_class_given_word(word, classes, vectorspace):
    prob = {}
    columns = vectorspace.columns
    for class_, _ in classes.items():
        wordcount = 0
        for col in columns:
            if col[0] == class_: 
                try:
                    wordcount += vectorspace[(class_, col[1])].loc[word]
                except KeyError: 
                    wordcount = 0
        prob[class_]  = wordcount
    nr, nc = vectorspace.shape
    tot = sum(prob.values())
    for k, v in prob.items():
        prob[k] = float((v + 1))/float((tot + nr))
        prob[k] = 1/float((tot + nr))
    return prob

prob_of_class_given_word('ASAS', prob_of_class, vectorspace)
# Out:
# {'data/training/agriculture_dairy': 0.00012938284383490748,
#  'data/training/it_software': 0.00012938284383490748,
#  'data/training/media_dotcom_entertainment': 0.00012938284383490748,
#  'data/training/travel_tourism': 0.00012938284383490748}

# %% [markdown]
# ### Probability of description given class

# %%
def prob_of_desc_given_class(desc, classes, vectorspace):
    prob = {}
    for class_, _ in classes.items():
        total_prob = 0
        for word in desc.split(' '):
            total_prob = float(total_prob) + math.log(float(prob_of_class_given_word(word, classes, vectorspace)[class_]))
        prob[class_] = total_prob
    return prob
text = 'job descriptiondeliver sales and profitability targets'
prob_of_desc_given_class(text, prob_of_class, vectorspace)
# Out:
# {'data/training/agriculture_dairy': -54.13985448559229,
#  'data/training/it_software': -54.13985448559229,
#  'data/training/media_dotcom_entertainment': -54.13985448559229,
#  'data/training/travel_tourism': -54.13985448559229}

# %% [markdown]
# ### Probability of class given description = Probability of description given class * Probability of class

# %%
def prob_of_class_given_desc(prob_of_desc_given_class, prob_of_class):
    prob = {}
    for class_, val in prob_of_class.items():
        prob[class_] = math.log(prob_of_class[class_]) + float(prob_of_desc_given_class[class_])
    return prob
a = prob_of_desc_given_class('good in communication skill', prob_of_class, vectorspace)
b = prob_of_class
prob_of_class_given_desc(a, b)
# Out:
# {'data/training/agriculture_dairy': -36.99424984112993,
#  'data/training/it_software': -38.31709798051086,
#  'data/training/media_dotcom_entertainment': -37.64884835157264,
#  'data/training/travel_tourism': -37.0761137112081}

# %% [markdown]
# ### Running model on test data

# %%
testing = extract_data('testing')
count = 0
expected_outcome = []
model_outcome = []
for k, v in testing.items():
    for i, item in enumerate(v):
        desc = item['jd_information']['description']
        if len(desc)>0:
            clean_desc = preprocess(desc)
            if type(clean_desc) is unicode:
                if len(clean_desc)>0:
                    a = prob_of_desc_given_class(clean_desc, prob_of_class, vectorspace)
                    b = prob_of_class
                    c = prob_of_class_given_desc(a, b)
                    expected_outcome.append(k)
                    model_outcome.append(c)
                    print count, k, max(c.iteritems(), key=operator.itemgetter(1))[0]
                    print "******************************************************************"
                    count += 1
#                     if count==3: break
#     break
# Out:
# 0 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 1 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 2 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 3 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 4 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 5 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 6 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 7 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 8 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 9 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 10 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 11 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 12 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 13 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 14 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 15 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 16 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 17 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 18 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 19 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 20 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 21 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 22 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 23 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 24 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 25 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 26 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 27 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 28 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 29 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 30 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 31 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 32 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 33 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 34 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 35 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 36 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 37 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 38 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 39 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 40 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 41 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 42 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 43 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 44 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 45 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 46 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 47 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 48 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 49 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 50 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 51 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 52 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 53 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 54 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 55 data/testing/agriculture_dairy data/training/agriculture_dairy
# ******************************************************************
# 56 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 57 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 58 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 59 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 60 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 61 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 62 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 63 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 64 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 65 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 66 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 67 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 68 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 69 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 70 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 71 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 72 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 73 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 74 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 75 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 76 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 77 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 78 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 79 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 80 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 81 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 82 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 83 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 84 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 85 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 86 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 87 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 88 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 89 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 90 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 91 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 92 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 93 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 94 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 95 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 96 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 97 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 98 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 99 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 100 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 101 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 102 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 103 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 104 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 105 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 106 data/testing/it_software data/training/agriculture_dairy
# ******************************************************************
# 107 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 108 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 109 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 110 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 111 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 112 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 113 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 114 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 115 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 116 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 117 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 118 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 119 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 120 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 121 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 122 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 123 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 124 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 125 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 126 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 127 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 128 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 129 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 130 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 131 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 132 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 133 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 134 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 135 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 136 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 137 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 138 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 139 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 140 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 141 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 142 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 143 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 144 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 145 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 146 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 147 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 148 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 149 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 150 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 151 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 152 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 153 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 154 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 155 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 156 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 157 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 158 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 159 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 160 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 161 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 162 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 163 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 164 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 165 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 166 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 167 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 168 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 169 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 170 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 171 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 172 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 173 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 174 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 175 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 176 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 177 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 178 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 179 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 180 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 181 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 182 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 183 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 184 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 185 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 186 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 187 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 188 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 189 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 190 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 191 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 192 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 193 data/testing/travel_tourism data/training/agriculture_dairy
# ******************************************************************
# 194 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 195 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 196 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 197 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 198 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 199 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 200 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 201 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 202 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 203 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 204 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 205 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 206 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 207 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 208 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 209 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 210 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 211 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 212 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 213 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 214 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 215 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 216 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 217 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 218 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 219 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 220 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 221 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 222 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 223 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 224 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 225 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 226 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 227 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 228 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 229 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 230 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 231 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 232 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 233 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 234 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 235 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 236 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 237 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 238 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 239 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 240 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 241 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 242 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 243 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 244 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 245 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 246 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************
# 247 data/testing/media_dotcom_entertainment data/training/agriculture_dairy
# ******************************************************************

# %% [markdown]
# ### Confusion Matrix

# %%
index = [key.split('/')[-1] for key in prob_of_class.keys()]
confusionmatrix = pd.DataFrame(index=index, columns=index)
confusionmatrix = confusionmatrix.fillna(0)
confusionmatrix
# Out:
#                             media_dotcom_entertainment  travel_tourism  \
# media_dotcom_entertainment                           0               0
# travel_tourism                                       0               0
# it_software                                          0               0
# agriculture_dairy                                    0               0
#
#                             it_software  agriculture_dairy
# media_dotcom_entertainment            0                  0
# travel_tourism                        0                  0
# it_software                           0                  0
# agriculture_dairy                     0                  0

# %% [markdown]
# ### Filling up confusion matrix

# %%
for true_label, predicted_label_dict in zip(expected_outcome, model_outcome):
    predicted_label = max(predicted_label_dict.iteritems(), key=operator.itemgetter(1))[0]
    confusionmatrix[predicted_label.split('/')[-1]].loc[true_label.split('/')[-1]] += 1
confusionmatrix
# Out:
#                             media_dotcom_entertainment  travel_tourism  \
# media_dotcom_entertainment                           0               0
# travel_tourism                                       0               0
# it_software                                          0               0
# agriculture_dairy                                    0               0
#
#                             it_software  agriculture_dairy
# media_dotcom_entertainment            0                 54
# travel_tourism                        0                 87
# it_software                           0                 51
# agriculture_dairy                     0                 56

# %% [markdown]
# ### Precision, Recall, Accuracy

# %%
for col in confusionmatrix.columns:
    precision = confusionmatrix[col].loc[col] / confusionmatrix[col].sum()
    recall = confusionmatrix[col].loc[col] / confusionmatrix.loc[col].sum()
    print "Precision for Industry ", col, " is ===>  ", precision
    print "Recall for Industry ", col, " is ===>  ", recall
# Out:
# Precision for Industry  media_dotcom_entertainment  is ===>   0
# Recall for Industry  media_dotcom_entertainment  is ===>   0
# Precision for Industry  travel_tourism  is ===>   0
# Recall for Industry  travel_tourism  is ===>   0
# Precision for Industry  it_software  is ===>   0
# Recall for Industry  it_software  is ===>   0
# Precision for Industry  agriculture_dairy  is ===>   0
# Recall for Industry  agriculture_dairy  is ===>   1
# /home/innovationchef/.local/lib/python2.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in long_scalars
